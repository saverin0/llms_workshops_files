# %% [markdown]
# <a href="https://colab.research.google.com/github/saverin0/llms_workshops_files/blob/main/oxford_llms_workshop_2_Topic_modelling_with_transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install transformers==4.57.0 datasets==3.2.0 bertopic==0.17.3 Pillow==11.1.0

# %%
import datasets
from bertopic import BERTopic
from PIL import Image
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
# Out:
# /usr/local/lib/python3.12/dist-packages/hdbscan/plots.py:448: SyntaxWarning: invalid escape sequence '\l'
#   axis.set_ylabel('$\lambda$ value')
# /usr/local/lib/python3.12/dist-packages/hdbscan/robust_single_linkage_.py:175: SyntaxWarning: invalid escape sequence '\{'
#   $max \{ core_k(a), core_k(b), 1/\alpha d(a,b) \}$.

# %%
data = datasets.load_dataset("rotten_tomatoes", split="train")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# train.parquet:   0%|          | 0.00/699k [00:00<?, ?B/s]
# validation.parquet:   0%|          | 0.00/90.0k [00:00<?, ?B/s]
# test.parquet:   0%|          | 0.00/92.2k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/8530 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1066 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1066 [00:00<?, ? examples/s]

# %%
data = data.to_pandas()

# %%
data = data.sample(n=1000, random_state=42).reset_index(drop=True)

# %%
docs = data["text"].tolist()
labels = data["label"].tolist()

# %% [markdown]
# ## 3. Our first topic model

# %%
topic_model = BERTopic()  # create an instance of topic model

# %%
topics, probs = topic_model.fit_transform(docs)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                            Name  \
# 0      -1    599                -1_the_of_and_to
# 1       0     99              0_the_to_its_movie
# 2       1     52         1_comedy_and_the_laughs
# 3       2     40               2_cast_and_the_as
# 4       3     36                 3_of_the_and_in
# 5       4     31          4_thriller_that_the_an
# 6       5     29              5_film_and_with_as
# 7       6     22        6_clunker_cold_dont_more
# 8       7     19         7_disney_movie_kids_the
# 9       8     19              8_art_of_hiphop_in
# 10      9     16  9_horror_creepy_spooky_haunted
# 11     10     13               10_her_she_is_ask
# 12     11     13            11_it_was_to_enjoyed
# 13     12     12          12_clever_its_it_whats
#
#                                        Representation  \
# 0       [the, of, and, to, is, in, that, as, its, it]
# 1   [the, to, its, movie, it, of, and, film, is, too]
# 2   [comedy, and, the, laughs, of, on, funny, it, ...
# 3   [cast, and, the, as, for, his, are, he, direct...
# 4   [of, the, and, in, love, drama, about, that, p...
# 5   [thriller, that, the, an, crime, and, of, murd...
# 6   [film, and, with, as, director, for, you, beno...
# 7   [clunker, cold, dont, more, that, caring, coar...
# 8   [disney, movie, kids, the, that, of, about, an...
# 9   [art, of, hiphop, in, and, artists, work, mess...
# 10  [horror, creepy, spooky, haunted, sum, wendigo...
# 11  [her, she, is, ask, to, actress, girl, because...
# 12  [it, was, to, enjoyed, fan, if, series, youre,...
# 13  [clever, its, it, whats, just, too, thing, is,...
#
#                                   Representative_Docs
# 0   [lacks the inspiration of the original and has...
# 1   [while somewhat less than it might have been ,...
# 2   [for 95 often hilarious minutes , [cho] riffs ...
# 3   [hawke draws out the best from his large cast ...
# 4   [cut through the layers of soap-opera emotion ...
# 5   [high crimes knows the mistakes that bad movie...
# 6   [a gently funny , sweetly adventurous film tha...
# 7   [a real clunker . a well-made , thoughtful , w...
# 8   [the film doesn't have enough innovation or pi...
# 9   [immersing us in the endlessly inventive , fie...
# 10  [shyamalan takes a potentially trite and overu...
# 11  [[macdowell] ventures beyond her abilities sev...
# 12  [if you're a fan of the series you'll love it ...
# 13  [much of what we see is horrible but it's also...

# %%
vectorizer_model = CountVectorizer(stop_words="english")
topic_model = BERTopic(vectorizer_model=vectorizer_model)

# %%
topics, probs = topic_model.fit_transform(docs)

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                              Name  \
# 0      -1    577       -1_film_movie_like_director
# 1       0    116            0_movie_film_just_like
# 2       1     62     1_thriller_horror_crime_flick
# 3       2     51    2_comedy_laughs_funny_romantic
# 4       3     36   3_cast_williams_performance_big
# 5       4     32      4_clunker_unfunny_treat_cold
# 6       5     27  5_love_empowerment_problems_tale
# 7       6     26         6_art_artists_hiphop_work
# 8       7     19   7_film_funny_specifically_truth
# 9       8     16       8_disney_adults_movie_adult
# 10      9     15      9_characters_ask_doesnt_care
# 11     10     12      10_dog_catholic_rabbits_film
# 12     11     11          11_idea_whats_tries_hard
#
#                                        Representation  \
# 0   [film, movie, like, director, little, way, tim...
# 1   [movie, film, just, like, films, time, story, ...
# 2   [thriller, horror, crime, flick, time, blade, ...
# 3   [comedy, laughs, funny, romantic, hilarious, r...
# 4   [cast, williams, performance, big, forget, ste...
# 5   [clunker, unfunny, treat, cold, dont, exercise...
# 6   [love, empowerment, problems, tale, drives, gr...
# 7   [art, artists, hiphop, work, heartfelt, messag...
# 8   [film, funny, specifically, truth, thoughtful,...
# 9   [disney, adults, movie, adult, teenagers, sini...
# 10  [characters, ask, doesnt, care, dramatic, does...
# 11  [dog, catholic, rabbits, film, goes, watching,...
# 12  [idea, whats, tries, hard, adobo, forever, fro...
#
#                                   Representative_Docs
# 0   [it's the best film of the year so far , the b...
# 1   [a simple , sometimes maddeningly slow film th...
# 2   [a psychological thriller with a genuinely spo...
# 3   [a romantic comedy enriched by a sharp eye for...
# 4   [the ensemble cast turns in a collectively ste...
# 5   [in xxx , diesel is that rare creature -- an a...
# 6   [merely ( and literally ) tosses around sex to...
# 7   [this is as powerful a set of evidence as you'...
# 8   [candid and comfortable ; a film that deftly b...
# 9   [the film doesn't have enough innovation or pi...
# 10  [while we want macdowell's character to retrie...
# 11  [if you recognize zeus ( the dog from snatch )...
# 12  [what's infuriating about full frontal is that...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="15fb6055-0bcd-4778-8078-e0ef3f14b98d" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15fb6055-0bcd-4778-8078-e0ef3f14b98d")) {                    Plotly.newPlot(                        "15fb6055-0bcd-4778-8078-e0ef3f14b98d",                        [{"customdata":[[0,"movie | film | just | like | films",116],[1,"thriller | horror | crime | flick | time",62],[2,"comedy | laughs | funny | romantic | hilarious",51],[3,"cast | williams | performance | big | forget",36],[4,"clunker | unfunny | treat | cold | dont",32],[5,"love | empowerment | problems | tale | drives",27],[6,"art | artists | hiphop | work | heartfelt",26],[7,"film | funny | specifically | truth | thoughtful",19],[8,"disney | adults | movie | adult | teenagers",16],[9,"characters | ask | doesnt | care | dramatic",15],[10,"dog | catholic | rabbits | film | goes",12],[11,"idea | whats | tries | hard | adobo",11]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[116,62,51,36,32,27,26,19,16,15,12,11],"sizemode":"area","sizeref":0.0725,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[12.777384,10.356833,-9.390205,12.111164,-9.077376,-9.866037,-10.351578,11.501898,12.261261,11.688017,11.473628,12.596015],"xaxis":"x","y":[3.1359668,3.7253141,5.450462,2.3199174,5.6997647,5.250842,5.3479695,3.229451,3.223541,1.8988887,4.3494225,3.746959],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"ty ...

# %%
topics_per_class = topic_model.topics_per_class(docs, classes=labels)

# %%
topic_model.visualize_topics_per_class(topics_per_class)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7397980b-8d54-424b-8b81-48a0761622e9" class="plotly-graph-div" style="height:900px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7397980b-8d54-424b-8b81-48a0761622e9")) {                    Plotly.newPlot(                        "7397980b-8d54-424b-8b81-48a0761622e9",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: movie, film, just, story, like","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: movie, film, bond, films, good"],"marker":{"color":"#E69F00"},"name":"0_movie_film_just_like","orientation":"h","visible":true,"x":[80,36],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: thriller, horror, crime, blade, slasher","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: thriller, horror, spooky, mix, creepy"],"marker":{"color":"#56B4E9"},"name":"1_thriller_horror_crime_flick","orientation":"h","visible":"legendonly","x":[37,25],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: comedy, laughs, romance, funny, jokes","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: comedy, laughs, funny, hilarious, romantic"],"marker":{"color":"#009E73"},"name":"2_comedy_laughs_funny_romantic","orientation":"h","visible":"legendonly","x":[16,35],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: cast, wrote, performers, big, directed","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: cast, williams, performance, forget, stevens"],"marker":{"color":"#F0E442"},"name":"3_cast_williams_performance_big","orientation":"h","visible":"legendonly","x":[11,25],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: clunker, unfunny, cold, dont, treat","\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: treat, savvy, significance, table, tattoo"],"marker":{"color":"#D55E00"},"name":"4_clunker_unfunny_treat_cold","orientation":"h","visible":"legendonly","x":[24,8],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: empowerment, problems, merely, love, explored","\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: love, drives, grief, yearning, desire"],"marker":{"color":"#0072B2"},"name":"5_love_empowerment_problems_tale","orientation":"h","visible":"legendonly","x":[10,17],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 6\u003c\u002fb\u003e\u003cbr\u003eWords: hiphop, wishful, value, payoff, negligible","\u003cb\u003eTopic 6\u003c\u002fb\u003e\u003cbr\u003eWords: art, artists, work, message, heartfelt"],"marker":{"color":"#CC79A7"},"name":"6_art_artists_hiphop_work","orientation":"h","visible":"legendonly","x":[6,20],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 7\u003c\u002fb\u003e\u003cbr\u003eWords: supplied, average, epps, benefits, moments","\u003cb\u003eTopic 7\u003c\u002fb\u003e\u003cbr\u003eWords: film, specifically, funny, truth, thoughtful"],"marker":{"color":"#E69F00"},"name":"7_film_funny_specifically_truth","orientation":"h","visible":"legendonly","x":[1,18],"y":[0,1],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 8\u003c\u002fb\u003e\u003cbr\u003eWords: disney, adults, real, movie, teenagers","\u003cb\u003eTopic 8\u003c\u002fb\u003e\u003cbr\u003eWords: disney, movie, sinister, biennial, tv"],"marker":{"color":"#56B4E9"},"name":"8_disney_adults_movie_adult","orientation":"h","visible":"legendonly","x":[8,8],"y":[0,1],"type":"bar"},{"hoverinfo" ...

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="31637670-7fa0-4da4-8266-be433018c594" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31637670-7fa0-4da4-8266-be433018c594")) {                    Plotly.newPlot(                        "31637670-7fa0-4da4-8266-be433018c594",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.029573591317621644,0.030941384129296475,0.03474709670299799,0.04217502843345419,0.060870302048993866],"y":["films  ","like  ","just  ","film  ","movie  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.026693267937177176,0.028612569288957675,0.03201087978844321,0.042918853933436515,0.07328919456266272],"y":["time  ","flick  ","crime  ","horror  ","thriller  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.04042658455834129,0.04524535861072686,0.049657355824316025,0.057062144263532885,0.10486806343322094],"y":["hilarious  ","romantic  ","funny  ","laughs  ","comedy  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.04255104752366232,0.045869571605843665,0.04688841499388062,0.05236831278831203,0.10014734023469095],"y":["forget  ","big  ","performance  ","williams  ","cast  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.0686570923195895,0.07169560062206116,0.0756181739020426,0.0756181739020426,0.1134272608530639],"y":["dont  ","cold  ","treat  ","unfunny  ","clunker  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.04030105984635736,0.04150053489728666,0.05632782341682765,0.05632782341682765,0.06118987012999717],"y":["drives  ","tale  ","problems  ","empowerment  ","love  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.04591034074921461,0.04617890465232229,0.048422163989904475,0.05196715611767133,0.08207289611832597],"y":["heartfelt  ","work  ","hiphop  ","artists  ","art  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.06237540104992774,0.06682623652440045,0.07899007729886043,0.09042368032008785,0.15636001282180612],"y":["thoughtful  ","truth  ","specifically  ","funny  ","film  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444 ...
